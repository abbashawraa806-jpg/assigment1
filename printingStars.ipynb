# %% [markdown]
# <a href="https://colab.research.google.com/github/abbashawraa806-jpg/assigment1/blob/main/printingStars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=1
while n<6:
     print ("*"*n)
     n=n+1
# Out:
# *
# **
# ***
# ****
# *****
